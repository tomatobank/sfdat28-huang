# %%
import requests     # how python goes onto the internet!
import re           # regex
import pandas as pd
from bs4 import BeautifulSoup # a python HTML parser (version 3)
from time import sleep

game =  pd.read_csv('/Users/benhuang/sfdat28-huang/game_company_social_media.csv')

# %%
game
# Out:
#                publisher                             game twitter_followers  \
# 0                     EA                               --             4.53M
# 1                     EA                      Battlefield             1.48M
# 2                     EA                             FIFA             4.15M
# 3                     EA       Star Wars the Old Republic              270K
# 4                     EA            Star Wars Battlefront              340K
# 5               Rockstar                               --             7.53M
# 6             Activision                               --              575K
# 7             Activision                     Call of Duty             3.18M
# 8                 Bungie                               --             1.75M
# 9                 Bungie                          Destiny             1.39M
# 10              Daybreak                               --               70K
# ...

# %%
url = game['facebook_url'][0]
r = requests.get(url)
url
# Out:
# 'https://www.facebook.com/EA/'

# %%
b = BeautifulSoup(r.text, 'html.parser')
b.prettify
# Out:
# <bound method BeautifulSoup.prettify of <!DOCTYPE html>\n\n<html class="no_js" id="facebook" lang="en">\n<head><meta charset="unicode-escape"/><meta content="default" id="meta_referrer" name="referrer"/><script>function envFlush(a){function b(c){for(var d in a)c[d]=a[d];}if(window.requireLazy){window.requireLazy(['Env'],b);}else{window.Env=window.Env||{};b(window.Env);}}envFlush({"ajaxpipe_token":"AXiWyPOsBdJFxM2j","lhsh":"XAQF0UqiP","timeslice_heartbeat_config":{"pollIntervalMs":33,"idleGapThresholdMs":60,"ignoredTimesliceNames":{"requestAnimationFrame":true,"Event listenHandler mousemove":true,"Event listenHandler mouseover":true,"Event listenHandler mouseout":true,"Event listenHandler scroll":true},"enableOnRequire":false},"shouldLogCounters":false,"timeslice_categories":{"react_render":true,"reflow":true}});</script><style></style><script>__DEV__=0;CavalryLogger=false;</script><noscript><meta content="0; URL=/EA/?_fb_noscript=1" http-equiv="refresh"/></noscript><title id="pageTit
# ...

# %%
b.findAll('people like this')
# Out:
# []

# %%
re_tag = re.compile("\_75e") 
div_tag = b.find('div', attrs={'class': re_tag}) 
print div_tag
# Out:
# None

# %%
from twitter import *
import json
consumer_key = 'P9TLMgifjxJOhIYlVbkzxA8bD'
consumer_secret = 'a0eBuc11vrBsd5KsQ4UNpAcTUoBM9m0m9EfqeUk61dZ3WXacpU'
token = '398994309-knlHw5bZUxj4kOH8Ri7zFDfSPcXY3GjjjNM6c6xB'
token_secret = '4bb5li7ERp0BEPOoctZUgbLhAd8tWZTmeGn9p3E4MjgW1'


t = Twitter(
    auth=OAuth(token, token_secret, consumer_key, consumer_secret))

# Get your "home" timeline
followers = []

for company_name in game['twitter_handle']:
    if pd.isnull(company_name):
        twitter_followers = 0
        followers.append(twitter_followers)
    else:
        twitter_followers = t.users.lookup(screen_name=company_name, _timeout=1)[0]['followers_count']
        followers.append(twitter_followers)

followers
# Out:
# [4537620,
#  1479528,
#  4166418,
#  270830,
#  340176,
#  7593161,
#  576770,
#  3184308,
#  1761189,
#  1395191,
#  70168,
#  42036,
#  10470752,
#  0,
#  0,
#  0,
#  0,
#  340870,
#  243888,
#  545835,
#  1029869,
#  727216,
#  1094821,
#  369512,
#  391930,
#  1203828,
#  132589,
#  5213277,
#  225939,
#  0,
#  140275,
#  0,
#  0,
#  0,
#  238534,
#  480470,
#  1935020,
#  224544,
#  5020898,
#  459811,
#  1388205,
#  1518691,
#  485499,
#  34356,
#  66266,
#  85453,
#  111969,
#  625282,
#  63940,
#  158460,
#  1210500,
#  6790,
#  98731,
#  0,
#  0,
#  65308,
#  5838,
#  5494]

# %%
game['followers'] = followers

# %%
game
# Out:
#                publisher                             game twitter_followers  \
# 0                     EA                               --             4.53M
# 1                     EA                      Battlefield             1.48M
# 2                     EA                             FIFA             4.15M
# 3                     EA       Star Wars the Old Republic              270K
# 4                     EA            Star Wars Battlefront              340K
# 5               Rockstar                               --             7.53M
# 6             Activision                               --              575K
# 7             Activision                     Call of Duty             3.18M
# 8                 Bungie                               --             1.75M
# 9                 Bungie                          Destiny             1.39M
# 10              Daybreak                               --               70K
# ...

# %%
yt_key = 'AIzaSyA7-uPKhKfwt1izAZ3bXkax2s18QN9KHa0'
#yt_api = 'https://www.googleapis.com/youtube/v3/channels?part=statistics&forUsername='+str(yt_channel)+'&key='+yt_key
yt_subs = []

for a,b in zip(game.youtube_username, game.youtube_id):
    if pd.isnull(a) and pd.isnull(b):
        sub_count = 0
        yt_subs.append(sub_count)
    elif pd.isnull(a):
        yt_api = 'https://www.googleapis.com/youtube/v3/channels?part=statistics&id='+str(b)+'&key='+yt_key
        r = requests.get(yt_api)
        if r.json()['items'] == []:
            sub_count = 0
        else:
            sub_count = r.json()['items'][0]['statistics']['subscriberCount']
        yt_subs.append(sub_count)
    else:
        yt_api = 'https://www.googleapis.com/youtube/v3/channels?part=statistics&forUsername='+str(a)+'&key='+yt_key
        r = requests.get(yt_api)
        if r.json()['items'] == []:
            sub_count = 0
        else:
            sub_count = r.json()['items'][0]['statistics']['subscriberCount']
        yt_subs.append(sub_count)
print yt_subs
# Out:
# [u'474741', u'1966780', u'206', u'160789', u'442053', u'2998064', u'0', u'4632844', u'394426', u'549390', u'2', u'66025', u'1723523', 0, 0, 0, 0, u'2', 0, u'250069', u'5066', u'275088', u'838775', u'201223', u'365299', u'955206', u'203981', u'1906859', u'93409', u'83747', 0, 0, 0, 0, u'63079', 0, u'956183', 0, u'402243', 0, u'405954', u'83624', u'46599', 0, u'114741', 0, u'49040', u'355793', u'23689', 0, u'115433', u'0', 0, 0, u'789', 0, 0, u'170']

# %%
game.insert(len(game.columns), 'youtube_subs',yt_subs)
game
# Out:
#                publisher                             game twitter_followers  \
# 0                     EA                               --             4.53M
# 1                     EA                      Battlefield             1.48M
# 2                     EA                             FIFA             4.15M
# 3                     EA       Star Wars the Old Republic              270K
# 4                     EA            Star Wars Battlefront              340K
# 5               Rockstar                               --             7.53M
# 6             Activision                               --              575K
# 7             Activision                     Call of Duty             3.18M
# 8                 Bungie                               --             1.75M
# 9                 Bungie                          Destiny             1.39M
# 10              Daybreak                               --               70K
# ...

# %%
del game['youtube_subs']
game
# Out:
#                publisher                             game twitter_followers  \
# 0                     EA                               --             4.53M
# 1                     EA                      Battlefield             1.48M
# 2                     EA                             FIFA             4.15M
# 3                     EA       Star Wars the Old Republic              270K
# 4                     EA            Star Wars Battlefront              340K
# 5               Rockstar                               --             7.53M
# 6             Activision                               --              575K
# 7             Activision                     Call of Duty             3.18M
# 8                 Bungie                               --             1.75M
# 9                 Bungie                          Destiny             1.39M
# 10              Daybreak                               --               70K
# ...

# %%
game.to_csv('game_company_appended.csv')
